# %% [markdown]
# # Import libs

# %%
import os
import sys
sys.path.append("../..")

from data.SythData import LinearSteps, SinusoidWaves

# %% [markdown]
# # Import data

# %% [markdown]
# ## Linear Data generator

# %%
data = LinearSteps(white_noise_level="max").get()

# %%
data[data.CPs == 1].count()
# Out:
# x      14
# CPs    14
# dtype: int64

# %%
data[:350].plot()
# Out:
# <Axes: xlabel='time'>

# %% [markdown]
# ## Sinusoid data generator

# %%
SinusoidWaves().get_sinusoid_array(0.5, 0.5)[0].shape
# Out:
# (169,)

# %%
SinusoidWaves(white_noise_level="min").get()[:350].plot()
# Out:
# <Axes: xlabel='time'>
